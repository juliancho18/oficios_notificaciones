# %% [markdown]
# Entrada

# %%
from loaders import Loaders
from utils import Utils
ld= Loaders()
utils= Utils()

# %%
# 01 - Cargar y visualizar base (Basenotificar.xlsx)

from loaders import Loaders
ld = Loaders()
path_archivo = r"input/Basenotificar.xlsx"  # <-- cambia si tu ruta es distinta
nombre_hoja = "query"                       # <-- tu hoja se llama "query"
df = ld.cargar_excel(path_archivo, nombre_hoja)

if df is None:
    raise FileNotFoundError(
        "No se pudo cargar el Excel. Revisa:\n"
        f"- Ruta: {path_archivo}\n"
        f"- Hoja: {nombre_hoja}\n"
        "Si el archivo expiró en el chat, vuelve a subirlo o cópialo a ./input/"
    )


print("✅ Base cargada correctamente")
print("Shape (filas, columnas):", df.shape)
print("\nColumnas:")
print(df.columns.tolist())

display(df.head(10))
display(df.info())

# Nulos por columna (top 30 para no saturar)
nulos = df.isna().sum().sort_values(ascending=False)
display(nulos.head(30))
# Out:
# ✅ Base cargada correctamente
# Shape (filas, columnas): (60, 23)
#
# Columnas:
# ['Notificador/Revisor', 'numero_expediente', 'Regional', 'Estado de la Actuacion', 'ACTUACION', 'Norma Aplicable', 'Permisivo/Sancionatorio', 'Recurso', 'Acto_Administrativo_No_y_fecha', 'Recurso_actoadministrativo', 'Ordena', 'Tipo de Acto Administrativo', 'Funcionario que expide', 'Nombre Notificado', 'Tipo de documento', 'Numero Documento', 'No. DireccionEfectiva', 'Autoriza Notificacion electrónica', 'Correo Electronico', 'Radicado de autorización Electronica', 'Modo de envío', 'Tipo de elemento', 'Ruta de acceso']
#               Notificador/Revisor  numero_expediente          Regional  \
# 0         Ana Maria Guzman Acosta              39618    Bajo Magdalena
# 1         Ana Maria Guzman Acosta              39618    Bajo Magdalena
# 2         Ana Maria Guzman Acosta              39618    Bajo Magdalena
# 3         Ana Maria Guzman Acosta              41735    Bajo Magdalena
# 4     Diana Carolina Morera Acuña              40381  Bogota la Calera
# 5  Andrea Claudia Martin Martinez              81918            Soacha
# 6  Andrea Claudia Martin Martinez              73233            Soacha
# 7  Andrea Claudia Martin Martinez              93441            Soacha
# 8         Ana Maria Guzman Acosta              44168    Bajo Magdalena
# 9         Ana Maria Guzman Acosta              44168    Bajo Magdalena
#
#        Estado de la Actuacion                 ACTUACION Norma Aplicable  \
# 0                     Enviado        EN OTRO ESTADO SAE        Ley 1437
# 1                     Enviado        EN OTRO ESTADO SAE        Ley 1437
# 2                     Enviado        EN OTRO ESTADO SAE        Ley 1437
# 3  En consulta de la Regional            EN CONSULTA DR        Ley 1437
# 4             Elaborar Oficio              COMUNICACION        Ley 1437
# 5             Elaborar Oficio  NOTIFICACIÓN ELECTRÓNICA        Ley 1437
# 6             Elaborar Oficio              COMUNICACION        Ley 1437
# 7             Elaborar Oficio              COMUNICACION        Ley 1437
# 8             Elaborar Oficio                     AVISO        Ley 1437
# 9             Elaborar Oficio                     AVISO        Ley 1437
#
#   Permisivo/Sancionatorio     Recurso  \
# 0           Sancionatorio     Recurso
# 1           Sancionatorio     Recurso
# 2           Sancionatorio     Recurso
# 3           Sancionatorio     Recurso
# 4           Sancionatorio  No recurso
# 5           Sancionatorio  No recurso
# 6           Sancionatorio  No recurso
# 7               Permisivo     Recurso
# 8           Sancionatorio     Recurso
# 9           Sancionatorio     Recurso
#
#                       Acto_Administrativo_No_y_fecha  \
# 0  Resolucion DJA No. 50257000923  del  29 Octubr...
# 1   RESOLUCIÓN No. 50257000923 del 29 de octubre ...
# 2   RESOLUCIÓN No. 50257000923 del 29 de octubre ...
# 3      Resolución N°4705 Del 31 de Diciembre de 2018
# 4  Resolución DRBC No.  01237000397  de  28 dicie...
# 5  Resolución DJA No. 50267000060 del 17 de febre...
# 6  Resolución DJUR No. 50257000727 del 23 de sept...
# 7  Resolución DRSOA No. 11257000090 del 02 de dic...
# 8  Resolución DJUR No. 50247000474 del 7 noviembr...
# 9  Resolución DJUR No. 50247000474 del 7 noviembr...
#
#   Recurso_actoadministrativo  ...  \
# 0                 Reposicion  ...
# 1                Reposicion   ...
# 2                 Reposicion  ...
# 3                 Reposicion  ...
# 4                  No Aplica  ...
# 5                  No Aplica  ...
# 6                  No aplica  ...
# 7                 Reposición  ...
# 8                Reposicion   ...
# 9                 Reposicion  ...
#
#                                    Nombre Notificado     Tipo de documento  \
# 0                       CARLOS ALBERTO SÁNCHEZ BARÓN  Cédula de ciudadania
# 1                     SADIN JESUS JIMENEZ HERNÁNDEZ   Cédula de ciudadania
# 2                           JOSE DONARDO URIBE GÓMEZ  Cédula de ciudadania
# 3                         MUNICIPIO DE PUERTO SALGAR                   NIT
# 4  PROCURADURIA 22 JUDICIAL II, AMBIENTAL Y AGRARIA"                   NIT
# 5  CONJUNTO RESIDENCIAL PORTAL DE CASALINDA PROPI...                   NIT
# 6  PROCURADURIA DELEGADA PARA ASUNTOS AMBIENTALES...                   NIT
# 7                       ALCALDIA MUNICIPAL DE SOACHA                   NIT
# 8                        FLOR GRISELDA PINTO ZABALA,  Cédula de ciudadania
# 9                    LUIS FERNANDO RODRÍGUEZ ZABALA,  Cédula de ciudadania
#
#   Numero Documento                              No. DireccionEfectiva  \
# 0         19388990                              Diagonal 87C No.82-46
# 1         10176897  CALLE 34 No.52-10 Naranjales Medellín (Antioquia)
# 2          8038334                                   Calle 1 No. 4-04
# 3       8999994138                   Transversal 11A Calle 11 # 25-27
# 4    899.999.071-0                   CARRERA 10 N°16-82 PISO 8 Bogotá
# 5    832.004.399-1                               Calle 30 No. 1 - 165
# 6    899.999.119-7                                  Cra 5 No. 15 - 60
# 7    800.094.755-7                            Calle 13 Nº 7-30 Soacha
# 8         20632169            Predio las delicias vereda Perú Guaduas
# 9         79003599                 Predio Cajon Vereda Raizal Guaduas
#
#   Autoriza Notificacion electrónica  \
# 0                             False
# 1                             False
# 2                             False
# 3                              True
# 4                             False
# 5                              True
# 6                              True
# 7                              True
# 8                             False
# 9                             False
#
#                           Correo Electronico  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3  alcaldia@puertosalgar-cundinamarca.gov.co
# 4            giovannipadillatellez@gmail.com
# 5                     portcasalinda@yahoo.es
# 6     procesosjudiciales@procuraduria.gov.co
# 7          contactenos@alcaldiasoacha.gov.co
# 8                                        NaN
# 9                                        NaN
#
#   Radicado de autorización Electronica          Modo de envío  \
# 0                                  NaN       Direccion fisica
# 1                                  NaN       Direccion fisica
# 2                                  NaN       Direccion fisica
# 3                         4.191101e+09       Direccion fisica
# 4                                  NaN  Direccion electronica
# 5                         1.124100e+10  Direccion electronica
# 6                                  NaN  Direccion electronica
# 7                                  NaN  Direccion electronica
# 8                                  NaN       Direccion fisica
# 9                                  NaN       Direccion fisica
#
#   Tipo de elemento                              Ruta de acceso
# 0         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 1         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 2         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 3         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 4         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 5         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 6         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 7         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 8         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 9         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
#
# [10 rows x 23 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Notificador/Revisor                   60 non-null     str
#  1   numero_expediente                     60 non-null     int64
#  2   Regional                              60 non-null     str
#  3   Estado de la Actuacion                60 non-null     str
#  4   ACTUACION                             60 non-null     str
#  5   Norma Aplicable                       60 non-null     str
#  6   Permisivo/Sancionatorio               60 non-null     str
#  7   Recurso                               60 non-null     str
#  8   Acto_Administrativo_No_y_fecha        60 non-null     str
#  9   Recurso_actoadministrativo            59 non-null     str
#  10  Ordena                                60 non-null     str
#  11  Tipo de Acto Administrativo           60 non-null     str
#  12  Funcionario que expide                60 non-null     str
#  13  Nombre Notificado                     60 non-null     str
#  14  Tipo de documento                     60 non-null     str
#  15  Numero Documento                      60 non-null     str
#  16  No. DireccionEfectiva                 60 non-null     str
#  17  Autoriza Notificacion electrónica     60 non-null     bool
#  18  Correo Electronico                    25 non-null     str
#  19  Radicado de autorización Electronica  12 non-null     float64
#  20  Modo de envío                         60 non-null     str
#  21  Tipo de elemento                      60 non-null     str
#  22  Ruta de acceso                        60 non-null     str
# dtypes: bool(1), float64(1), int64(1), str(20)
# memory usage: 10.5 KB
# None
# Radicado de autorización Electronica    48
# Correo Electronico                      35
# Recurso_actoadministrativo               1
# Estado de la Actuacion                   0
# Notificador/Revisor                      0
# numero_expediente                        0
# Regional                                 0
# Permisivo/Sancionatorio                  0
# Norma Aplicable                          0
# ACTUACION                                0
# Recurso                                  0
# Tipo de Acto Administrativo              0
# Funcionario que expide                   0
# Acto_Administrativo_No_y_fecha           0
# Ordena                                   0
# Tipo de documento                        0
# Nombre Notificado                        0
# No. DireccionEfectiva                    0
# Numero Documento                         0
# Autoriza Notificacion electrónica        0
# Modo de envío                            0
# Tipo de elemento                         0
# Ruta de acceso                           0
# dtype: int64

# %% [markdown]
# Segmentos de elaborar oficios

# %%
# ============================================================
# 02 - Filtrar SOLO los registros con "Elaborar Oficio"
#      (columna correcta: "Estado de la Actuacion")
# ============================================================

import unicodedata

def _norm_txt(x: str) -> str:
    x = "" if x is None else str(x)
    x = x.strip().upper()
    x = " ".join(x.split())
    x = unicodedata.normalize("NFKD", x).encode("ascii", "ignore").decode("ascii")
    return x

col_estado_act = "Estado de la Actuacion"
valor_objetivo = "Elaborar Oficio"


if col_estado_act not in df.columns:
    # Si por algún motivo viene con otra escritura, mostramos candidatas
    candidatas = [c for c in df.columns if "estado" in _norm_txt(c) and "actu" in _norm_txt(c)]
    raise KeyError(
        f"No existe la columna '{col_estado_act}'.\n"
        f"Candidatas encontradas: {candidatas}\n"
        f"Columnas disponibles: {df.columns.tolist()}"
    )

tmp = df.copy()
tmp["_estado_norm"] = tmp[col_estado_act].map(_norm_txt)

df_filtrado = tmp[tmp["_estado_norm"] == _norm_txt(valor_objetivo)].drop(columns=["_estado_norm"]).copy()
df_filtrado.reset_index(drop=True, inplace=True)

print("✅ Filtrado aplicado por Estado de la Actuacion == 'Elaborar Oficio'")
print("Shape original:", df.shape)
print("Shape filtrado :", df_filtrado.shape)

display(df_filtrado.head(10))
display(df[col_estado_act].astype(str).value_counts(dropna=False).head(20))
# Out:
# ✅ Filtrado aplicado por Estado de la Actuacion == 'Elaborar Oficio'
# Shape original: (60, 23)
# Shape filtrado : (47, 23)
#                 Notificador/Revisor  numero_expediente          Regional  \
# 0       Diana Carolina Morera Acuña              40381  Bogota la Calera
# 1    Andrea Claudia Martin Martinez              81918            Soacha
# 2    Andrea Claudia Martin Martinez              73233            Soacha
# 3    Andrea Claudia Martin Martinez              93441            Soacha
# 4           Ana Maria Guzman Acosta              44168    Bajo Magdalena
# 5           Ana Maria Guzman Acosta              44168    Bajo Magdalena
# 6           Ana Maria Guzman Acosta              45586    Bajo Magdalena
# 7           Ana Maria Guzman Acosta              49743    Bajo Magdalena
# 8  Laura Stephania Martinez Leandro              44696    Alto Magdalena
# 9  Laura Stephania Martinez Leandro              53016    Alto Magdalena
#
#   Estado de la Actuacion                 ACTUACION Norma Aplicable  \
# 0        Elaborar Oficio              COMUNICACION        Ley 1437
# 1        Elaborar Oficio  NOTIFICACIÓN ELECTRÓNICA        Ley 1437
# 2        Elaborar Oficio              COMUNICACION        Ley 1437
# 3        Elaborar Oficio              COMUNICACION        Ley 1437
# 4        Elaborar Oficio                     AVISO        Ley 1437
# 5        Elaborar Oficio                     AVISO        Ley 1437
# 6        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 7        Elaborar Oficio            EN CONSULTA DR        Ley 1437
# 8        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 9        Elaborar Oficio            PUBLICAR AVISO        Ley 1437
#
#   Permisivo/Sancionatorio     Recurso  \
# 0           Sancionatorio  No recurso
# 1           Sancionatorio  No recurso
# 2           Sancionatorio  No recurso
# 3               Permisivo     Recurso
# 4           Sancionatorio     Recurso
# 5           Sancionatorio     Recurso
# 6           Sancionatorio     Recurso
# 7           Sancionatorio     Recurso
# 8           Sancionatorio     Recurso
# 9           Sancionatorio     Recurso
#
#                       Acto_Administrativo_No_y_fecha  \
# 0  Resolución DRBC No.  01237000397  de  28 dicie...
# 1  Resolución DJA No. 50267000060 del 17 de febre...
# 2  Resolución DJUR No. 50257000727 del 23 de sept...
# 3  Resolución DRSOA No. 11257000090 del 02 de dic...
# 4  Resolución DJUR No. 50247000474 del 7 noviembr...
# 5  Resolución DJUR No. 50247000474 del 7 noviembr...
# 6          Resolución No. 1387 de 31 de mayo de 2017
# 7    Resolución No. 4741 del 31 de diciembre de 2018
# 8  RESOLUCIÓN DJUR No. 50257000463 del 11 de juli...
# 9  RESOLUCIÓN DJUR No. 50257000556 del 21 de agos...
#
#   Recurso_actoadministrativo  ...  \
# 0                  No Aplica  ...
# 1                  No Aplica  ...
# 2                  No aplica  ...
# 3                 Reposición  ...
# 4                Reposicion   ...
# 5                 Reposicion  ...
# 6                 Reposición  ...
# 7                 Reposición  ...
# 8      Recurso de reposición  ...
# 9      recurso de reposición  ...
#
#                                    Nombre Notificado     Tipo de documento  \
# 0  PROCURADURIA 22 JUDICIAL II, AMBIENTAL Y AGRARIA"                   NIT
# 1  CONJUNTO RESIDENCIAL PORTAL DE CASALINDA PROPI...                   NIT
# 2  PROCURADURIA DELEGADA PARA ASUNTOS AMBIENTALES...                   NIT
# 3                       ALCALDIA MUNICIPAL DE SOACHA                   NIT
# 4                        FLOR GRISELDA PINTO ZABALA,  Cédula de ciudadania
# 5                    LUIS FERNANDO RODRÍGUEZ ZABALA,  Cédula de ciudadania
# 6                                     ALIRIO VANEGAS  Cédula de ciudadania
# 7            ESTACIÓN DE SERVICIO TERPEL MONTECRISTO                   NIT
# 8                     MANUEL DAVID CARVAJAL BERMUDEZ  Cédula de ciudadania
# 9               MARTHA DE LA CONCEPCION GOMEZ CASTRO  Cédula de ciudadania
#
#   Numero Documento                              No. DireccionEfectiva  \
# 0    899.999.071-0                   CARRERA 10 N°16-82 PISO 8 Bogotá
# 1    832.004.399-1                               Calle 30 No. 1 - 165
# 2    899.999.119-7                                  Cra 5 No. 15 - 60
# 3    800.094.755-7                            Calle 13 Nº 7-30 Soacha
# 4         20632169            Predio las delicias vereda Perú Guaduas
# 5         79003599                 Predio Cajon Vereda Raizal Guaduas
# 6          3079328             CALLE 10 N° 3- 30 LA HOYITA CAPARRAPI
# 7      83009521301                       Carrera 7 No. 75 - 51 Bogota
# 8       11.228.476           Calle 3 No 23 B - 23 Barrio La Esperanza
# 9         39550755  HC LA CONCEPCION KM 9 VIA GIRARDOT VEREDA GUAB...
#
#   Autoriza Notificacion electrónica                      Correo Electronico  \
# 0                             False         giovannipadillatellez@gmail.com
# 1                              True                  portcasalinda@yahoo.es
# 2                              True  procesosjudiciales@procuraduria.gov.co
# 3                              True       contactenos@alcaldiasoacha.gov.co
# 4                             False                                     NaN
# 5                             False                                     NaN
# 6                             False                                     NaN
# 7                              True                viviana.rodas@terpel.com
# 8                              True           manuel_carvajal04@hotmail.com
# 9                             False                     yedanisel@gmail.com
#
#   Radicado de autorización Electronica          Modo de envío  \
# 0                                  NaN  Direccion electronica
# 1                         1.124100e+10  Direccion electronica
# 2                                  NaN  Direccion electronica
# 3                                  NaN  Direccion electronica
# 4                                  NaN       Direccion fisica
# 5                                  NaN       Direccion fisica
# 6                                  NaN       Direccion fisica
# 7                         2.020114e+10  Direccion electronica
# 8                         3.246002e+09  Direccion electronica
# 9                                  NaN  Direccion desconocida
#
#   Tipo de elemento                              Ruta de acceso
# 0         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 1         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 2         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 3         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 4         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 5         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 6         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 7         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 8         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
# 9         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes
#
# [10 rows x 23 columns]
# Estado de la Actuacion
# Elaborar Oficio               47
# Enviado                        7
# En consulta de la Regional     6
# Name: count, dtype: int64

# %% [markdown]
# Agregamos Regionales con nombre de director e indicador

# %%
df_filtrado = utils.agregar_info_regional(df_filtrado, col_regional="Regional")

print("✅ Columnas agregadas:", ["INDICADOR", "DIRECTOR_REGIONAL"])
display(df_filtrado[["Regional", "INDICADOR", "DIRECTOR_REGIONAL"]].head(15))
# Out:
# ✅ Columnas agregadas: ['INDICADOR', 'DIRECTOR_REGIONAL']
#             Regional INDICADOR                DIRECTOR_REGIONAL
# 0   Bogota la Calera      DRBC      YUBER YESID CARDENAS PULIDO
# 1             Soacha     DRSOA       CESAR AUGUSTO RICO MAYORGA
# 2             Soacha     DRSOA       CESAR AUGUSTO RICO MAYORGA
# 3             Soacha     DRSOA       CESAR AUGUSTO RICO MAYORGA
# 4     Bajo Magdalena      DRBM   JUAN FILIBERTO COTRINO GUEVARA
# 5     Bajo Magdalena      DRBM   JUAN FILIBERTO COTRINO GUEVARA
# 6     Bajo Magdalena      DRBM   JUAN FILIBERTO COTRINO GUEVARA
# 7     Bajo Magdalena      DRBM   JUAN FILIBERTO COTRINO GUEVARA
# 8     Alto Magdalena      DRAM  CAMILA ANDREA VELASQUEZ BAQUERO
# 9     Alto Magdalena      DRAM  CAMILA ANDREA VELASQUEZ BAQUERO
# 10    Alto Magdalena      DRAM  CAMILA ANDREA VELASQUEZ BAQUERO
# 11    Alto Magdalena      DRAM  CAMILA ANDREA VELASQUEZ BAQUERO
# 12  Bogota la Calera      DRBC      YUBER YESID CARDENAS PULIDO
# 13  Bogota la Calera      DRBC      YUBER YESID CARDENAS PULIDO
# 14  Bogota la Calera      DRBC      YUBER YESID CARDENAS PULIDO

# %%
df_filtrado
# Out:
#                  Notificador/Revisor  numero_expediente          Regional  \
# 0        Diana Carolina Morera Acuña              40381  Bogota la Calera
# 1     Andrea Claudia Martin Martinez              81918            Soacha
# 2     Andrea Claudia Martin Martinez              73233            Soacha
# 3     Andrea Claudia Martin Martinez              93441            Soacha
# 4            Ana Maria Guzman Acosta              44168    Bajo Magdalena
# 5            Ana Maria Guzman Acosta              44168    Bajo Magdalena
# 6            Ana Maria Guzman Acosta              45586    Bajo Magdalena
# 7            Ana Maria Guzman Acosta              49743    Bajo Magdalena
# 8   Laura Stephania Martinez Leandro              44696    Alto Magdalena
# 9   Laura Stephania Martinez Leandro              53016    Alto Magdalena
# 10  Laura Stephania Martinez Leandro              57314    Alto Magdalena
# 11  Laura Stephania Martinez Leandro              74305    Alto Magdalena
# 12       Diana Carolina Morera Acuña              40388  Bogota la Calera
# 13       Diana Carolina Morera Acuña              40388  Bogota la Calera
# 14       Diana Carolina Morera Acuña              40388  Bogota la Calera
# 15       Diana Carolina Morera Acuña              41480  Bogota la Calera
# 16       Diana Carolina Morera Acuña              41480  Bogota la Calera
# 17       Diana Carolina Morera Acuña              41564  Bogota la Calera
# 18    Andrea Claudia Martin Martinez              69585            Soacha
# 19       Diana Carolina Morera Acuña              41564  Bogota la Calera
# 20       Diana Carolina Morera Acuña              41570  Bogota la Calera
# 21       Diana Carolina Morera Acuña              41874  Bogota la Calera
# 22       Diana Carolina Morera Acuña              41874  Bogota la Calera
# 23       Diana Carolina Morera Acuña              41874  Bogota la Calera
# 24       Diana Carolina Morera Acuña              41874  Bogota la Calera
# 25       Diana Carolina Morera Acuña              41874  Bogota la Calera
# 26    Andrea Claudia Martin Martinez              69585            Soacha
# 27    Andrea Claudia Martin Martinez              78981            Soacha
# 28           Ana Maria Guzman Acosta              53586    Bajo Magdalena
# 29    Andrea Claudia Martin Martinez              44874            Soacha
# 30    Andrea Claudia Martin Martinez              44874            Soacha
# 31           Ana Maria Guzman Acosta              54346    Bajo Magdalena
# 32  Laura Stephania Martinez Leandro              83445    Alto Magdalena
# 33  Laura Stephania Martinez Leandro              89106    Alto Magdalena
# 34  Laura Stephania Martinez Leandro              89438    Alto Magdalena
# 35           Ana Maria Guzman Acosta              54765    Bajo Magdalena
# 36           Ana Maria Guzman Acosta              56766    Bajo Magdalena
# 37           Ana Maria Guzman Acosta              60182    Bajo Magdalena
# 38           Ana Maria Guzman Acosta              62944    Bajo Magdalena
# 39           Ana Maria Guzman Acosta              65453    Bajo Magdalena
# 40           Ana Maria Guzman Acosta              65453    Bajo Magdalena
# 41           Ana Maria Guzman Acosta              65453    Bajo Magdalena
# 42           Ana Maria Guzman Acosta              65453    Bajo Magdalena
# 43           Ana Maria Guzman Acosta              65453    Bajo Magdalena
# 44           Ana Maria Guzman Acosta              65453    Bajo Magdalena
# 45           Ana Maria Guzman Acosta              65453    Bajo Magdalena
# 46           Ana Maria Guzman Acosta              65467    Bajo Magdalena
#
#    Estado de la Actuacion                 ACTUACION Norma Aplicable  \
# 0         Elaborar Oficio              COMUNICACION        Ley 1437
# 1         Elaborar Oficio  NOTIFICACIÓN ELECTRÓNICA        Ley 1437
# 2         Elaborar Oficio              COMUNICACION        Ley 1437
# 3         Elaborar Oficio              COMUNICACION        Ley 1437
# 4         Elaborar Oficio                     AVISO        Ley 1437
# 5         Elaborar Oficio                     AVISO        Ley 1437
# 6         Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 7         Elaborar Oficio            EN CONSULTA DR        Ley 1437
# 8         Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 9         Elaborar Oficio            PUBLICAR AVISO        Ley 1437
# 10        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 11        Elaborar Oficio                     AVISO        Ley 1437
# 12        Elaborar Oficio                  CITACION        Ley 1437
# 13        Elaborar Oficio                  CITACION        Ley 1437
# 14        Elaborar Oficio                     AVISO        Ley 1437
# 15        Elaborar Oficio                     AVISO        Ley 1437
# 16        Elaborar Oficio              COMUNICACION        Ley 1437
# 17        Elaborar Oficio                  CITACION        Ley 1437
# 18        Elaborar Oficio  NOTIFICACIÓN ELECTRÓNICA        Ley 1437
# 19        Elaborar Oficio                  CITACION        Ley 1437
# 20        Elaborar Oficio            PUBLICAR AVISO        Ley 1437
# 21        Elaborar Oficio                    EDICTO        Ley 1437
# 22        Elaborar Oficio         PUBLICAR CITACION        Ley 1437
# 23        Elaborar Oficio                  CITACION        Ley 1437
# 24        Elaborar Oficio                  CITACION        Ley 1437
# 25        Elaborar Oficio              COMUNICACION        Ley 1437
# 26        Elaborar Oficio                  CITACION        Ley 1437
# 27        Elaborar Oficio            PUBLICAR AVISO        Ley 1437
# 28        Elaborar Oficio              COMUNICACION        Ley 1437
# 29        Elaborar Oficio  NOTIFICACIÓN ELECTRÓNICA             CCA
# 30        Elaborar Oficio  NOTIFICACIÓN ELECTRÓNICA             CCA
# 31        Elaborar Oficio                     AVISO        Ley 1437
# 32        Elaborar Oficio              COMUNICACION        Ley 1437
# 33        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 34        Elaborar Oficio            PUBLICAR AVISO        Ley 1437
# 35        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 36        Elaborar Oficio           PARA EJECUTORIA        Ley 1333
# 37        Elaborar Oficio           PARA EJECUTORIA        Ley 1333
# 38        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 39        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 40        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 41        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 42        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 43        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 44        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
# 45        Elaborar Oficio              COMUNICACION        Ley 1437
# 46        Elaborar Oficio           PARA EJECUTORIA        Ley 1437
#
#    Permisivo/Sancionatorio     Recurso  \
# 0            Sancionatorio  No recurso
# 1            Sancionatorio  No recurso
# 2            Sancionatorio  No recurso
# 3                Permisivo     Recurso
# 4            Sancionatorio     Recurso
# 5            Sancionatorio     Recurso
# 6            Sancionatorio     Recurso
# 7            Sancionatorio     Recurso
# 8            Sancionatorio     Recurso
# 9            Sancionatorio     Recurso
# 10           Sancionatorio     Recurso
# 11           Sancionatorio     Recurso
# 12           Sancionatorio     Recurso
# 13           Sancionatorio     Recurso
# 14           Sancionatorio     Recurso
# 15           Sancionatorio     Recurso
# 16           Sancionatorio     Recurso
# 17           Sancionatorio     Recurso
# 18           Sancionatorio     Recurso
# 19           Sancionatorio     Recurso
# 20           Sancionatorio     Recurso
# 21           Sancionatorio     Recurso
# 22           Sancionatorio     Recurso
# 23           Sancionatorio     Recurso
# 24           Sancionatorio     Recurso
# 25           Sancionatorio     Recurso
# 26           Sancionatorio     Recurso
# 27           Sancionatorio     Recurso
# 28           Sancionatorio     Recurso
# 29           Sancionatorio     Recurso
# 30           Sancionatorio     Recurso
# 31           Sancionatorio     Recurso
# 32           Sancionatorio     Recurso
# 33           Sancionatorio     Recurso
# 34           Sancionatorio     Recurso
# 35           Sancionatorio     Recurso
# 36           Sancionatorio     Recurso
# 37           Sancionatorio     Recurso
# 38           Sancionatorio     Recurso
# 39           Sancionatorio     Recurso
# 40           Sancionatorio     Recurso
# 41           Sancionatorio     Recurso
# 42           Sancionatorio     Recurso
# 43           Sancionatorio     Recurso
# 44           Sancionatorio     Recurso
# 45           Sancionatorio     Recurso
# 46           Sancionatorio     Recurso
#
#                        Acto_Administrativo_No_y_fecha  \
# 0   Resolución DRBC No.  01237000397  de  28 dicie...
# 1   Resolución DJA No. 50267000060 del 17 de febre...
# 2   Resolución DJUR No. 50257000727 del 23 de sept...
# 3   Resolución DRSOA No. 11257000090 del 02 de dic...
# 4   Resolución DJUR No. 50247000474 del 7 noviembr...
# 5   Resolución DJUR No. 50247000474 del 7 noviembr...
# 6           Resolución No. 1387 de 31 de mayo de 2017
# 7     Resolución No. 4741 del 31 de diciembre de 2018
# 8   RESOLUCIÓN DJUR No. 50257000463 del 11 de juli...
# 9   RESOLUCIÓN DJUR No. 50257000556 del 21 de agos...
# 10  RESOLUCIÓN DRAM No. 03257000146 del 24 de sept...
# 11  RESOLUCIÓN DJA No. 50257001140 del 24 de dicie...
# 12  Resolución DRBC No.  01237000081  de  31 marzo...
# 13  Resolucion DRBC No.  01237000081  de  31 marzo...
# 14  Resolucion DRBC No.  01237000081  de  31 marzo...
# 15  RESOLUCIÓN DJUR No.  50237000469  de  31 MAR. ...
# 16  Resolucion DJUR No.  50237000469  de  31 marzo...
# 17  RESOLUCIÓN DJUR No.  50237000472  de  31 MAR. ...
# 18  Resolución DJA No. 50257000963 del 10 de novie...
# 19  Resolucion DJUR No.  50237000472  de  31 marzo...
# 20  Resolucion DJUR No.  50237002990  de  28 dicie...
# 21  Resolucion DJUR No.  50237003006  de  29 dicie...
# 22  Resolucion DJUR No.  50237003006  de  29 dicie...
# 23  Resolucion DJUR No.  50237003006  de  29 dicie...
# 24  Resolucion DJUR No.  50237003006  de  29 dicie...
# 25  Resolucion DJUR No.  50237003006  de  29 dicie...
# 26  Resolución DJA No. 50257000963 del 10 de novie...
# 27  Resolución DJUR No. 50257000729 del 25 de sept...
# 28   Resolución DJUR No. 50257000611 del 25 Agosto...
# 29  Resolución DJUR No. 50257000693 del 15 de sept...
# 30  Resolución DJUR No. 50257000693 del 15 de sept...
# 31  Resolución DJUR No. 50257000839 del 21 octubre...
# 32  RESOLUCIÓN DJA No. 50257000926 del 29 de octub...
# 33  RESOLUCIÓN DRAM No. 03257000046 del 18 de marz...
# 34  RESOLUCIÓN DJA No. 50257001135 del 23 de dicie...
# 35  Resolución DJUR No. 50227002078 del 21 de dici...
# 36  Resolución DJUR No. 50247000665  del  24 Dicie...
# 37   Resolución DJUR No. 50257000785  del 9 de Oct...
# 38  Resolución DJUR No. 50257000828 del  21 Octubr...
# 39  Resolución DJUR No. 50237001079 del 22 de juni...
# 40  Resolución DJUR No. 50237001079 del 22 de juni...
# 41  Resolución DJUR No. 50237001079 del 22 de juni...
# 42  Resolución DJUR No. 50237001079 del 22 de juni...
# 43  Resolución DJUR No. 50237001079 del 22 de juni...
# 44  Resolución DJUR No. 50237001079 del 22 de juni...
# 45  Resolución DJUR No. 50237001079 del 22 junio d...
# 46  Resolución DJA No.  50257000935  del  31 de  O...
#
#    Recurso_actoadministrativo  ... Autoriza Notificacion electrónica  \
# 0                   No Aplica  ...                             False
# 1                   No Aplica  ...                              True
# 2                   No aplica  ...                              True
# 3                  Reposición  ...                              True
# 4                 Reposicion   ...                             False
# 5                  Reposicion  ...                             False
# 6                  Reposición  ...                             False
# 7                  Reposición  ...                              True
# 8       Recurso de reposición  ...                              True
# 9       recurso de reposición  ...                             False
# 10      recurso de reposición  ...                              True
# 11      recurso de reposición  ...                             False
# 12                Reposicion   ...                             False
# 13                Reposicion   ...                             False
# 14                 Reposicion  ...                             False
# 15                Reposicion   ...                             False
# 16                reposicion   ...                             False
# 17                Reposicion   ...                             False
# 18                 Reposición  ...                              True
# 19                Reposicion   ...                             False
# 20                Resposicion  ...                             False
# 21                Reposicion   ...                             False
# 22                Reposicion   ...                             False
# 23                Reposicion   ...                             False
# 24               Resposicion   ...                             False
# 25                 Reposicion  ...                             False
# 26                 Reposición  ...                             False
# 27                 Reposición  ...                             False
# 28                 Reposicion  ...                             False
# 29                 Reposición  ...                              True
# 30                 Reposición  ...                              True
# 31                 Reposicion  ...                              True
# 32      recurso de reposición  ...                             False
# 33      recurso de reposición  ...                             False
# 34      recurso de reposición  ...                             False
# 35                 Reposicion  ...                             False
# 36                 Reposicion  ...                             False
# 37                Reposicion   ...                             False
# 38                 Reposicion  ...                             False
# 39                 Reosicion   ...                             False
# 40                 Reposicion  ...                             False
# 41                 Reposicion  ...                             False
# 42                Reposicion   ...                             False
# 43                 Reposicion  ...                             False
# 44                 Reposicion  ...                             False
# 45                 Reposicion  ...                              True
# 46                 Reposicion  ...                              True
#
#                         Correo Electronico  \
# 0          giovannipadillatellez@gmail.com
# 1                   portcasalinda@yahoo.es
# 2   procesosjudiciales@procuraduria.gov.co
# 3        contactenos@alcaldiasoacha.gov.co
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                 viviana.rodas@terpel.com
# 8            manuel_carvajal04@hotmail.com
# 9                      yedanisel@gmail.com
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15            mcpachonv@compensarsalud.com
# 16  comunicacionespgn@procuraduria.gov.co
# 17                                     NaN
# 18     rodriguezcruzangelsneyder@gmail.com
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22            ANGELICA_PRECIADO@HOTMAIL.ES
# 23           carlosapreciado2009@gmail.com
# 24                   camargo737@gmail.com
# 25   comunicacionespgn@procuraduria.gov.co
# 26                                     NaN
# 27              alveiroburbano@hotmail.com
# 28         giovannipadillatellez@gmail.com
# 29   notijudicial_bene@cundinamarca.gov.co
# 30               mauriciolmj1712@gmail.com
# 31                 psanchez@prodeca.com.co
# 32                                     NaN
# 33                                     NaN
# 34                                     NaN
# 35                                     NaN
# 36                                     NaN
# 37                                     NaN
# 38    juridico@guaduas-cundinamarca.gov.co
# 39                                     NaN
# 40                                     NaN
# 41                                     NaN
# 42                                     NaN
# 43                                     NaN
# 44                                     NaN
# 45                                     NaN
# 46         inversionesgamburibe@outlook.es
#
#    Radicado de autorización Electronica          Modo de envío  \
# 0                                   NaN  Direccion electronica
# 1                          1.124100e+10  Direccion electronica
# 2                                   NaN  Direccion electronica
# 3                                   NaN  Direccion electronica
# 4                                   NaN       Direccion fisica
# 5                                   NaN       Direccion fisica
# 6                                   NaN       Direccion fisica
# 7                          2.020114e+10  Direccion electronica
# 8                          3.246002e+09  Direccion electronica
# 9                                   NaN  Direccion desconocida
# 10                                  NaN       Direccion fisica
# 11                                  NaN       Direccion fisica
# 12                                  NaN       Direccion fisica
# 13                                  NaN       Direccion fisica
# 14                                  NaN       Direccion fisica
# 15                                  NaN  Direccion electronica
# 16                                  NaN  Direccion electronica
# 17                                  NaN       Direccion fisica
# 18                         2.320000e+02  Direccion electronica
# 19                                  NaN       Direccion fisica
# 20                                  NaN       Direccion fisica
# 21                                  NaN       Direccion fisica
# 22                                  NaN  Direccion electronica
# 23                                  NaN  Direccion electronica
# 24                                  NaN  Direccion electronica
# 25                                  NaN  Direccion electronica
# 26                                  NaN       Direccion fisica
# 27                                  NaN  Direccion electronica
# 28                                  NaN       Direccion fisica
# 29                         2.020114e+10  Direccion electronica
# 30                         1.060000e+02  Direccion electronica
# 31                         2.024113e+10  Direccion electronica
# 32                                  NaN       Direccion fisica
# 33                                  NaN       Direccion fisica
# 34                                  NaN       Direccion fisica
# 35                                  NaN       Direccion fisica
# 36                                  NaN       Direccion fisica
# 37                                  NaN       Direccion fisica
# 38                                  NaN       Direccion fisica
# 39                                  NaN       Direccion fisica
# 40                                  NaN       Direccion fisica
# 41                                  NaN       Direccion fisica
# 42                                  NaN       Direccion fisica
# 43                                  NaN       Direccion fisica
# 44                                  NaN       Direccion fisica
# 45                                  NaN  Direccion electronica
# 46                         2.024112e+10  Direccion electronica
#
#    Tipo de elemento                              Ruta de acceso INDICADOR  \
# 0          Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 1          Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 2          Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 3          Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 4          Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 5          Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 6          Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 7          Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 8          Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRAM
# 9          Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRAM
# 10         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRAM
# 11         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRAM
# 12         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 13         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 14         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 15         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 16         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 17         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 18         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 19         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 20         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 21         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 22         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 23         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 24         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 25         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 26         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 27         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 28         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 29         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 30         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 31         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 32         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRAM
# 33         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRAM
# 34         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRAM
# 35         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 36         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 37         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 38         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 39         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 40         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 41         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 42         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 43         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 44         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 45         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
# 46         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
#
#                   DIRECTOR_REGIONAL  \
# 0       YUBER YESID CARDENAS PULIDO
# 1        CESAR AUGUSTO RICO MAYORGA
# 2        CESAR AUGUSTO RICO MAYORGA
# 3        CESAR AUGUSTO RICO MAYORGA
# 4    JUAN FILIBERTO COTRINO GUEVARA
# 5    JUAN FILIBERTO COTRINO GUEVARA
# 6    JUAN FILIBERTO COTRINO GUEVARA
# 7    JUAN FILIBERTO COTRINO GUEVARA
# 8   CAMILA ANDREA VELASQUEZ BAQUERO
# 9   CAMILA ANDREA VELASQUEZ BAQUERO
# 10  CAMILA ANDREA VELASQUEZ BAQUERO
# 11  CAMILA ANDREA VELASQUEZ BAQUERO
# 12      YUBER YESID CARDENAS PULIDO
# 13      YUBER YESID CARDENAS PULIDO
# 14      YUBER YESID CARDENAS PULIDO
# 15      YUBER YESID CARDENAS PULIDO
# 16      YUBER YESID CARDENAS PULIDO
# 17      YUBER YESID CARDENAS PULIDO
# 18       CESAR AUGUSTO RICO MAYORGA
# 19      YUBER YESID CARDENAS PULIDO
# 20      YUBER YESID CARDENAS PULIDO
# 21      YUBER YESID CARDENAS PULIDO
# 22      YUBER YESID CARDENAS PULIDO
# 23      YUBER YESID CARDENAS PULIDO
# 24      YUBER YESID CARDENAS PULIDO
# 25      YUBER YESID CARDENAS PULIDO
# 26       CESAR AUGUSTO RICO MAYORGA
# 27       CESAR AUGUSTO RICO MAYORGA
# 28   JUAN FILIBERTO COTRINO GUEVARA
# 29       CESAR AUGUSTO RICO MAYORGA
# 30       CESAR AUGUSTO RICO MAYORGA
# 31   JUAN FILIBERTO COTRINO GUEVARA
# 32  CAMILA ANDREA VELASQUEZ BAQUERO
# 33  CAMILA ANDREA VELASQUEZ BAQUERO
# 34  CAMILA ANDREA VELASQUEZ BAQUERO
# 35   JUAN FILIBERTO COTRINO GUEVARA
# 36   JUAN FILIBERTO COTRINO GUEVARA
# 37   JUAN FILIBERTO COTRINO GUEVARA
# 38   JUAN FILIBERTO COTRINO GUEVARA
# 39   JUAN FILIBERTO COTRINO GUEVARA
# 40   JUAN FILIBERTO COTRINO GUEVARA
# 41   JUAN FILIBERTO COTRINO GUEVARA
# 42   JUAN FILIBERTO COTRINO GUEVARA
# 43   JUAN FILIBERTO COTRINO GUEVARA
# 44   JUAN FILIBERTO COTRINO GUEVARA
# 45   JUAN FILIBERTO COTRINO GUEVARA
# 46   JUAN FILIBERTO COTRINO GUEVARA
#
#                               DIRECCION_REGIONAL      MUNICIPIO_REGIONAL
# 0                     Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 1   Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 2   Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 3   Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 4                  Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 5                  Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 6                  Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 7                  Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 8             Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 9             Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 10            Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 11            Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 12                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 13                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 14                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 15                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 16                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 17                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 18  Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 19                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 20                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 21                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 22                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 23                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 24                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 25                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 26  Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 27  Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 28                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 29  Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 30  Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 31                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 32            Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 33            Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 34            Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 35                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 36                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 37                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 38                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 39                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 40                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 41                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 42                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 43                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 44                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 45                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 46                 Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
#
# [47 rows x 27 columns]

# %% [markdown]
# Direcciones de cada regional

# %%
df_filtrado = utils.agregar_info_regional(df_filtrado, col_regional="Regional")

display(
    df_filtrado[["Regional", "INDICADOR", "DIRECTOR_REGIONAL", "DIRECCION_REGIONAL", "MUNICIPIO_REGIONAL"]]
    .head(15)
)
# Out:
#             Regional INDICADOR                DIRECTOR_REGIONAL  \
# 0   Bogota la Calera      DRBC      YUBER YESID CARDENAS PULIDO
# 1             Soacha     DRSOA       CESAR AUGUSTO RICO MAYORGA
# 2             Soacha     DRSOA       CESAR AUGUSTO RICO MAYORGA
# 3             Soacha     DRSOA       CESAR AUGUSTO RICO MAYORGA
# 4     Bajo Magdalena      DRBM   JUAN FILIBERTO COTRINO GUEVARA
# 5     Bajo Magdalena      DRBM   JUAN FILIBERTO COTRINO GUEVARA
# 6     Bajo Magdalena      DRBM   JUAN FILIBERTO COTRINO GUEVARA
# 7     Bajo Magdalena      DRBM   JUAN FILIBERTO COTRINO GUEVARA
# 8     Alto Magdalena      DRAM  CAMILA ANDREA VELASQUEZ BAQUERO
# 9     Alto Magdalena      DRAM  CAMILA ANDREA VELASQUEZ BAQUERO
# 10    Alto Magdalena      DRAM  CAMILA ANDREA VELASQUEZ BAQUERO
# 11    Alto Magdalena      DRAM  CAMILA ANDREA VELASQUEZ BAQUERO
# 12  Bogota la Calera      DRBC      YUBER YESID CARDENAS PULIDO
# 13  Bogota la Calera      DRBC      YUBER YESID CARDENAS PULIDO
# 14  Bogota la Calera      DRBC      YUBER YESID CARDENAS PULIDO
#
#                               DIRECCION_REGIONAL      MUNICIPIO_REGIONAL
# 0                     Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 1   Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 2   Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 3   Trans. 7 F N° 26-38 Barrio El Nogal - Soacha    Soacha, Cundinamarca
# 4                  Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 5                  Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 6                  Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 7                  Calle 4 N° 5-68 Camellón Real   Guaduas, Cundinamarca
# 8             Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 9             Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 10            Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 11            Calle 21 No. 8 – 23 Barrio Granada  Girardot, Cundinamarca
# 12                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 13                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca
# 14                    Carrera 10 N° 16-82 piso 4    Bogotá, Cundinamarca

# %% [markdown]
# Validacion de dataframe en asignaciones

# %%
print("📌 RESUMEN GENERAL")
print("="*50)
print("Filas:", df_filtrado.shape[0])
print("Columnas:", df_filtrado.shape[1])
print("="*50)

display(df_filtrado.head(5))
# Out:
# 📌 RESUMEN GENERAL
# ==================================================
# Filas: 47
# Columnas: 27
# ==================================================
#               Notificador/Revisor  numero_expediente          Regional  \
# 0     Diana Carolina Morera Acuña              40381  Bogota la Calera
# 1  Andrea Claudia Martin Martinez              81918            Soacha
# 2  Andrea Claudia Martin Martinez              73233            Soacha
# 3  Andrea Claudia Martin Martinez              93441            Soacha
# 4         Ana Maria Guzman Acosta              44168    Bajo Magdalena
#
#   Estado de la Actuacion                 ACTUACION Norma Aplicable  \
# 0        Elaborar Oficio              COMUNICACION        Ley 1437
# 1        Elaborar Oficio  NOTIFICACIÓN ELECTRÓNICA        Ley 1437
# 2        Elaborar Oficio              COMUNICACION        Ley 1437
# 3        Elaborar Oficio              COMUNICACION        Ley 1437
# 4        Elaborar Oficio                     AVISO        Ley 1437
#
#   Permisivo/Sancionatorio     Recurso  \
# 0           Sancionatorio  No recurso
# 1           Sancionatorio  No recurso
# 2           Sancionatorio  No recurso
# 3               Permisivo     Recurso
# 4           Sancionatorio     Recurso
#
#                       Acto_Administrativo_No_y_fecha  \
# 0  Resolución DRBC No.  01237000397  de  28 dicie...
# 1  Resolución DJA No. 50267000060 del 17 de febre...
# 2  Resolución DJUR No. 50257000727 del 23 de sept...
# 3  Resolución DRSOA No. 11257000090 del 02 de dic...
# 4  Resolución DJUR No. 50247000474 del 7 noviembr...
#
#   Recurso_actoadministrativo  ... Autoriza Notificacion electrónica  \
# 0                  No Aplica  ...                             False
# 1                  No Aplica  ...                              True
# 2                  No aplica  ...                              True
# 3                 Reposición  ...                              True
# 4                Reposicion   ...                             False
#
#                        Correo Electronico  \
# 0         giovannipadillatellez@gmail.com
# 1                  portcasalinda@yahoo.es
# 2  procesosjudiciales@procuraduria.gov.co
# 3       contactenos@alcaldiasoacha.gov.co
# 4                                     NaN
#
#   Radicado de autorización Electronica          Modo de envío  \
# 0                                  NaN  Direccion electronica
# 1                         1.124100e+10  Direccion electronica
# 2                                  NaN  Direccion electronica
# 3                                  NaN  Direccion electronica
# 4                                  NaN       Direccion fisica
#
#   Tipo de elemento                              Ruta de acceso INDICADOR  \
# 0         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 1         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 2         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 3         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 4         Elemento  sites/NOTIFICACIONES2026/Lists/expedientes      DRBM
#
#                 DIRECTOR_REGIONAL  \
# 0     YUBER YESID CARDENAS PULIDO
# 1      CESAR AUGUSTO RICO MAYORGA
# 2      CESAR AUGUSTO RICO MAYORGA
# 3      CESAR AUGUSTO RICO MAYORGA
# 4  JUAN FILIBERTO COTRINO GUEVARA
#
#                              DIRECCION_REGIONAL     MUNICIPIO_REGIONAL
# 0                    Carrera 10 N° 16-82 piso 4   Bogotá, Cundinamarca
# 1  Trans. 7 F N° 26-38 Barrio El Nogal - Soacha   Soacha, Cundinamarca
# 2  Trans. 7 F N° 26-38 Barrio El Nogal - Soacha   Soacha, Cundinamarca
# 3  Trans. 7 F N° 26-38 Barrio El Nogal - Soacha   Soacha, Cundinamarca
# 4                 Calle 4 N° 5-68 Camellón Real  Guaduas, Cundinamarca
#
# [5 rows x 27 columns]

# %% [markdown]
# DataFrame con abogados independientes

# %%
import importlib
import utils as utils_module
importlib.reload(utils_module)

from utils import Utils
utils = Utils()

print("✅ utils recargado. Métodos disponibles (filtrado):")
print([m for m in dir(utils) if "persona" in m or "cruce" in m])
# Out:
# ✅ utils recargado. Métodos disponibles (filtrado):
# ['agregar_fila_cruce', 'agregar_fila_cruce_excel', 'agregar_fila_cruce_word', 'exportar_excels_por_persona', 'partir_por_persona_con_cruce']

# %% [markdown]
# complemento textual

# %%
col_origen = "Tipo de Acto Administrativo"

df_filtrado = utils.agregar_columnas_del_de_la(
    df_filtrado,
    col_origen=col_origen,
    col_articulo="articulo_preposicion",
    col_frase="descripcion_con_articulo",
    minusculas=True
)

df_filtrado[[col_origen, "articulo_preposicion", "descripcion_con_articulo"]].head(20)
# Out:
#    Tipo de Acto Administrativo articulo_preposicion descripcion_con_articulo
# 0                   Resolución                de la         de la resolución
# 1                   Resolución                de la         de la resolución
# 2                   Resolución                de la         de la resolución
# 3                   Resolución                de la         de la resolución
# 4                   Resolución                de la         de la resolución
# 5                   Resolución                de la         de la resolución
# 6                   Resolución                de la         de la resolución
# 7                   Resolución                de la         de la resolución
# 8                   Resolución                de la         de la resolución
# 9                   Resolución                de la         de la resolución
# 10                  Resolución                de la         de la resolución
# 11                  Resolución                de la         de la resolución
# 12                  Resolución                de la         de la resolución
# 13                  Resolución                de la         de la resolución
# 14                  Resolución                de la         de la resolución
# 15                  Resolución                de la         de la resolución
# 16                  Resolución                de la         de la resolución
# 17                  Resolución                de la         de la resolución
# 18                  Resolución                de la         de la resolución
# 19                  Resolución                de la         de la resolución

# %% [markdown]
# Exportar excel abogado

# %%
resumen = utils.exportar_excels_por_persona(
    df=df_filtrado,
    col_persona="Notificador/Revisor",
    carpeta_salida="output_abogados",
    nombre_prefix="OFICIOS",
    add_fila_cruce=True,
    col_fila_cruce="No_Fila_Cruce",
    offset_fila_cruce=1
)

display(resumen)
# Out:
#                             persona  filas  \
# 0           Ana Maria Guzman Acosta     18
# 1    Andrea Claudia Martin Martinez      8
# 2       Diana Carolina Morera Acuña     14
# 3  Laura Stephania Martinez Leandro      7
#
#                                         ruta_archivo
# 0  output_abogados\OFICIOS_Ana_Maria_Guzman_Acost...
# 1  output_abogados\OFICIOS_Andrea_Claudia_Martin_...
# 2  output_abogados\OFICIOS_Diana_Carolina_Morera_...
# 3  output_abogados\OFICIOS_Laura_Stephania_Martin...

# %% [markdown]
# # FASE 2. CREACION DE OFICIOS

# %%
resumen = utils.exportar_excels_por_persona(
    df=df_filtrado,
    col_persona="Notificador/Revisor",
    carpeta_salida="output_abogados",
    nombre_prefix="OFICIOS",
    add_fila_cruce=True,
    col_fila_cruce="No_Fila_Cruce",
    offset_fila_cruce=1
)
display(resumen)
# Out:
#                             persona  filas  \
# 0           Ana Maria Guzman Acosta     18
# 1    Andrea Claudia Martin Martinez      8
# 2       Diana Carolina Morera Acuña     14
# 3  Laura Stephania Martinez Leandro      7
#
#                                         ruta_archivo
# 0  output_abogados\OFICIOS_Ana_Maria_Guzman_Acost...
# 1  output_abogados\OFICIOS_Andrea_Claudia_Martin_...
# 2  output_abogados\OFICIOS_Diana_Carolina_Morera_...
# 3  output_abogados\OFICIOS_Laura_Stephania_Martin...

# %%
resumen = utils.exportar_excels_por_persona(
    df=df_filtrado,
    col_persona="Notificador/Revisor",
    carpeta_salida="output_abogados",
    nombre_prefix="OFICIOS",
    add_fila_cruce=True,
    col_fila_cruce="No_Fila_Cruce",
    offset_fila_cruce=1
)
display(resumen)
# Out:
#                             persona  filas  \
# 0           Ana Maria Guzman Acosta     18
# 1    Andrea Claudia Martin Martinez      8
# 2       Diana Carolina Morera Acuña     14
# 3  Laura Stephania Martinez Leandro      7
#
#                                         ruta_archivo
# 0  output_abogados\OFICIOS_Ana_Maria_Guzman_Acost...
# 1  output_abogados\OFICIOS_Andrea_Claudia_Martin_...
# 2  output_abogados\OFICIOS_Diana_Carolina_Morera_...
# 3  output_abogados\OFICIOS_Laura_Stephania_Martin...

# %%
df_filtrado = utils.agregar_info_regional(df_filtrado, col_regional="Regional")
df_filtrado = utils.agregar_columnas_del_de_la(df_filtrado, col_origen="Tipo de Acto Administrativo")

# %% [markdown]
# EXCEL OPERATIVO GENERAL DE OFICIOS

# %%
def buscar_col(df, posibles):
    def norm(s):
        return str(s).strip().lower().replace(" ", "").replace("_", "").replace(".", "")
    cols = list(df.columns)
    cols_norm = {norm(c): c for c in cols}
    for p in posibles:
        if norm(p) in cols_norm:
            return cols_norm[norm(p)]
    for p in posibles:
        for c in cols:
            if norm(p) in norm(c):
                return c
    return None

col_notificador = buscar_col(df_filtrado, ["Notificador/Revisor", "Notificador"])
col_estado      = buscar_col(df_filtrado, ["Estado_Actuacion", "Estado Actuacion", "Estado Actuación", "Estado"])
col_tipo_oficio = buscar_col(df_filtrado, ["Tipo_Oficio", "Tipo de Acto Administrativo", "Tipo Oficio"])
col_expediente  = buscar_col(df_filtrado, ["numero_expediente", "No. Exp.", "Expediente"])
col_notificado  = buscar_col(df_filtrado, ["Nombre_Notificado", "Nombre Notificado", "Notificado"])

print("Detectadas:")
print("col_notificador:", col_notificador)
print("col_estado:", col_estado)
print("col_tipo_oficio:", col_tipo_oficio)
print("col_expediente:", col_expediente)
print("col_notificado:", col_notificado)
# Out:
# Detectadas:
# col_notificador: Notificador/Revisor
# col_estado: Estado de la Actuacion
# col_tipo_oficio: Tipo de Acto Administrativo
# col_expediente: numero_expediente
# col_notificado: Nombre Notificado

# %%
res_operativo = utils.exportar_excel_oficios_y_ejecutorias_por_notificador(
    df=df_filtrado,
    col_notificador=col_notificador,
    col_estado_actuacion=col_estado,
    col_tipo_oficio=col_tipo_oficio,
    col_expediente=col_expediente,
    col_notificado=col_notificado,
    carpeta_salida="output_abogados",
    nombre_archivo="RESUMEN_OFICIOS_Y_EJECUTORIAS.xlsx",
)

display(res_operativo)
# Out:
#                             abogado  oficios_por_crear  ejecutorias  \
# 0           Ana Maria Guzman Acosta                 18            0
# 1    Andrea Claudia Martin Martinez                  8            0
# 2       Diana Carolina Morera Acuña                 14            0
# 3  Laura Stephania Martinez Leandro                  7            0
#
#                                           ruta_excel
# 0  output_abogados\Ana_Maria_Guzman_Acosta\RESUME...
# 1  output_abogados\Andrea_Claudia_Martin_Martinez...
# 2  output_abogados\Diana_Carolina_Morera_Acuña\RE...
# 3  output_abogados\Laura_Stephania_Martinez_Leand...

# %% [markdown]
# EJECUTAR WORD

# %%
# ¿Qué métodos tiene tu objeto utils?
[m for m in dir(utils) if "plantilla" in m.lower() or "word" in m.lower()]
# Out:
# ['_mapa_plantillas_docx',
#  '_obtener_ruta_plantilla_por_tipo',
#  '_ruta_plantillas',
#  'agregar_fila_cruce_word',
#  'generar_words_desde_plantilla',
#  'generar_words_desde_tipo_oficio']

# %%
import importlib
import utils as utils_module

importlib.reload(utils_module)

utils = utils_module.Utils()

print("¿Existe generar_words_desde_plantilla?:",
      hasattr(utils, "generar_words_desde_plantilla"))
# Out:
# ¿Existe generar_words_desde_plantilla?: True

# %%
import os
import sys
import pandas as pd

print("Python del notebook:", sys.executable)

# 0) Validación: df_filtrado existe
if "df_filtrado" not in globals():
    raise NameError("df_filtrado NO existe. Ejecuta primero la parte donde cargas/creas df_filtrado.")

print("✅ df_filtrado OK. Filas:", len(df_filtrado), "Columnas:", len(df_filtrado.columns))
display(df_filtrado.head(3))
# Out:
# Python del notebook: c:\Users\JULIANCHO ROBLES\Desktop\PROYECTOS GITHUB\oficios_notificaciones\venv\Scripts\python.exe
# ✅ df_filtrado OK. Filas: 47 Columnas: 29
#               Notificador/Revisor  numero_expediente          Regional  \
# 0     Diana Carolina Morera Acuña              40381  Bogota la Calera
# 1  Andrea Claudia Martin Martinez              81918            Soacha
# 2  Andrea Claudia Martin Martinez              73233            Soacha
#
#   Estado de la Actuacion                 ACTUACION Norma Aplicable  \
# 0        Elaborar Oficio              COMUNICACION        Ley 1437
# 1        Elaborar Oficio  NOTIFICACIÓN ELECTRÓNICA        Ley 1437
# 2        Elaborar Oficio              COMUNICACION        Ley 1437
#
#   Permisivo/Sancionatorio     Recurso  \
# 0           Sancionatorio  No recurso
# 1           Sancionatorio  No recurso
# 2           Sancionatorio  No recurso
#
#                       Acto_Administrativo_No_y_fecha  \
# 0  Resolución DRBC No.  01237000397  de  28 dicie...
# 1  Resolución DJA No. 50267000060 del 17 de febre...
# 2  Resolución DJUR No. 50257000727 del 23 de sept...
#
#   Recurso_actoadministrativo  ... Radicado de autorización Electronica  \
# 0                  No Aplica  ...                                  NaN
# 1                  No Aplica  ...                         1.124100e+10
# 2                  No aplica  ...                                  NaN
#
#            Modo de envío Tipo de elemento  \
# 0  Direccion electronica         Elemento
# 1  Direccion electronica         Elemento
# 2  Direccion electronica         Elemento
#
#                                Ruta de acceso INDICADOR  \
# 0  sites/NOTIFICACIONES2026/Lists/expedientes      DRBC
# 1  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
# 2  sites/NOTIFICACIONES2026/Lists/expedientes     DRSOA
#
#              DIRECTOR_REGIONAL                            DIRECCION_REGIONAL  \
# 0  YUBER YESID CARDENAS PULIDO                    Carrera 10 N° 16-82 piso 4
# 1   CESAR AUGUSTO RICO MAYORGA  Trans. 7 F N° 26-38 Barrio El Nogal - Soacha
# 2   CESAR AUGUSTO RICO MAYORGA  Trans. 7 F N° 26-38 Barrio El Nogal - Soacha
#
#      MUNICIPIO_REGIONAL articulo_preposicion  descripcion_con_articulo
# 0  Bogotá, Cundinamarca                de la          de la resolución
# 1  Soacha, Cundinamarca                de la          de la resolución
# 2  Soacha, Cundinamarca                de la          de la resolución
#
# [3 rows x 29 columns]

# %% [markdown]
# crear oficios

# %%
COL_ESTADO = "Estado de la Actuacion"   # <- tu nombre real
COL_ACTUACION = "ACTUACION"            # <- tu nombre real

# 1) Filtrar SOLO elaborar oficio
df_oficios = df_filtrado.copy()

df_oficios = df_oficios[
    df_oficios[COL_ESTADO].astype(str).str.strip().str.lower().eq("elaborar oficio")
].copy()

# 2) Excluir ejecutorias por texto en ACTUACION (si aplica)
df_oficios = df_oficios[
    ~df_oficios[COL_ACTUACION].astype(str).str.upper().str.contains("EJECUTORIA", na=False)
].copy()

print("✅ Filas para Word (oficios sin ejecutorias):", len(df_oficios))
display(df_oficios[[COL_ESTADO, COL_ACTUACION, "numero_expediente", "Nombre Notificado", "Notificador/Revisor"]].head(10))
# Out:
# ✅ Filas para Word (oficios sin ejecutorias): 32
#    Estado de la Actuacion                 ACTUACION  numero_expediente  \
# 0         Elaborar Oficio              COMUNICACION              40381
# 1         Elaborar Oficio  NOTIFICACIÓN ELECTRÓNICA              81918
# 2         Elaborar Oficio              COMUNICACION              73233
# 3         Elaborar Oficio              COMUNICACION              93441
# 4         Elaborar Oficio                     AVISO              44168
# 5         Elaborar Oficio                     AVISO              44168
# 7         Elaborar Oficio            EN CONSULTA DR              49743
# 9         Elaborar Oficio            PUBLICAR AVISO              53016
# 11        Elaborar Oficio                     AVISO              74305
# 12        Elaborar Oficio                  CITACION              40388
#
#                                     Nombre Notificado  \
# 0   PROCURADURIA 22 JUDICIAL II, AMBIENTAL Y AGRARIA"
# 1   CONJUNTO RESIDENCIAL PORTAL DE CASALINDA PROPI...
# 2   PROCURADURIA DELEGADA PARA ASUNTOS AMBIENTALES...
# 3                        ALCALDIA MUNICIPAL DE SOACHA
# 4                         FLOR GRISELDA PINTO ZABALA,
# 5                     LUIS FERNANDO RODRÍGUEZ ZABALA,
# 7             ESTACIÓN DE SERVICIO TERPEL MONTECRISTO
# 9                MARTHA DE LA CONCEPCION GOMEZ CASTRO
# 11                                FERNANDO REY MORENO
# 12                       HECTOR JAIRO SARMIENTO GOMEZ
#
#                  Notificador/Revisor
# 0        Diana Carolina Morera Acuña
# 1     Andrea Claudia Martin Martinez
# 2     Andrea Claudia Martin Martinez
# 3     Andrea Claudia Martin Martinez
# 4            Ana Maria Guzman Acosta
# 5            Ana Maria Guzman Acosta
# 7            Ana Maria Guzman Acosta
# 9   Laura Stephania Martinez Leandro
# 11  Laura Stephania Martinez Leandro
# 12       Diana Carolina Morera Acuña

# %%
# NORMALIZAR COLUMNAS PARA PLANTILLA WORD


df_oficios = df_oficios.copy()

alias_cols = {
    "Numero Documento": "Numero_Documento",
    "Correo Electronico": "Correo_Electronico",
    "No. DireccionEfectiva": "No_DireccionEfectiva",
    "Modo de envío": "Modo_de_envío",
}

faltan_origen = [c for c in alias_cols.keys() if c not in df_oficios.columns]
if faltan_origen:
    print("❌ Faltan estas columnas ORIGEN en df_oficios (revisa el nombre exacto):")
    for c in faltan_origen:
        print("   -", repr(c))
else:
    for origen, destino in alias_cols.items():
        df_oficios[destino] = df_oficios[origen]

    print("✅ Columnas creadas para plantilla:")
    for _, destino in alias_cols.items():
        print("   -", destino)

# (Opcional pero recomendado) Verifica rápido que ya existen:
check = ["Numero_Documento", "Correo_Electronico", "No_DireccionEfectiva", "Modo_de_envío"]
print("\n🔎 Verificación:")
for c in check:
    print(c, "->", "OK" if c in df_oficios.columns else "❌ NO")
# Out:
# ✅ Columnas creadas para plantilla:
#    - Numero_Documento
#    - Correo_Electronico
#    - No_DireccionEfectiva
#    - Modo_de_envío
#
# 🔎 Verificación:
# Numero_Documento -> OK
# Correo_Electronico -> OK
# No_DireccionEfectiva -> OK
# Modo_de_envío -> OK

# %%
import importlib
import utils as utils_mod

importlib.reload(utils_mod)
utils = utils_mod.Utils()  # o como estés instanciando tu clase
print("Existe generar_words_desde_plantilla?", hasattr(utils, "generar_words_desde_plantilla"))
# Out:
# Existe generar_words_desde_plantilla? True

# %%
def generar_words_desde_plantilla(
    self,
    df,
    plantilla_path,
    carpeta_salida="output_abogados",
    col_notificador="Notificador/Revisor",
    col_subcarpeta=None,                 # ej: "ACTUACION"
    nombre_archivo_cols=None,            # ej: ["numero_expediente", "Nombre Notificado"]
    col_map=None,                        # {"Numero_Documento": "Numero Documento", ...}
    abrir_cierre="«»",                   # delimitadores de tu plantilla
    max_nombre=140
):
    import os
    import re
    import pandas as pd

    try:
        from docx import Document
    except Exception as e:
        raise ImportError(
            "No se pudo importar python-docx. Instala con: pip install python-docx"
        ) from e

    if df is None or len(df) == 0:
        return pd.DataFrame(columns=["fila", "ruta_docx"])

    if not os.path.exists(plantilla_path):
        raise FileNotFoundError(f"No existe la plantilla en: {plantilla_path}")

    col_map = col_map or {}
    nombre_archivo_cols = nombre_archivo_cols or []

    def _safe_txt(x):
        if x is None:
            return ""
        if isinstance(x, float) and pd.isna(x):
            return ""
        if pd.isna(x):
            return ""
        return str(x)

    def _sanitize(s):
        s = _safe_txt(s).strip()
        s = re.sub(r"[\\/:*?\"<>|]+", "_", s)
        s = re.sub(r"\s+", " ", s).strip()
        if len(s) > max_nombre:
            s = s[:max_nombre].strip()
        return s or "SIN_DATO"

    # Reemplazo simple (si el token está partido entre runs, puede perder formato).
    # Funciona bien si tus «campos» están escritos como texto normal.
    def _replace_in_paragraph(paragraph, replacements):
        text = paragraph.text
        changed = False
        for k, v in replacements.items():
            if k in text:
                text = text.replace(k, v)
                changed = True
        if changed:
            paragraph.text = text

    def _replace_in_table(table, replacements):
        for row in table.rows:
            for cell in row.cells:
                for p in cell.paragraphs:
                    _replace_in_paragraph(p, replacements)
                for t in cell.tables:
                    _replace_in_table(t, replacements)

    izq, der = abrir_cierre[0], abrir_cierre[-1]  # « »
    generados = []

    for i, row in df.reset_index(drop=True).iterrows():

        notificador = _sanitize(row.get(col_notificador, "SIN_NOTIFICADOR"))
        subcarp = _sanitize(row.get(col_subcarpeta, "")) if col_subcarpeta else ""

        # Carpeta final:
        # carpeta_salida/<NOTIFICADOR>/<SUBCARPETA>/WORDS/
        ruta_dir = os.path.join(carpeta_salida, notificador)
        if subcarp:
            ruta_dir = os.path.join(ruta_dir, subcarp)
        ruta_dir = os.path.join(ruta_dir, "WORDS")
        os.makedirs(ruta_dir, exist_ok=True)

        # Nombre del archivo
        partes = []
        for c in nombre_archivo_cols:
            partes.append(_sanitize(row.get(c, "")))
        base_name = "_".join([p for p in partes if p and p != "SIN_DATO"]) or f"doc_{i+1}"
        nombre_doc = f"{base_name}.docx"
        ruta_out = os.path.join(ruta_dir, nombre_doc)

        # Construir replacements desde la fila
        replacements = {}

        # 1) Todos los campos directos que existan en el DF:
        for col in df.columns:
            key = f"{izq}{col}{der}"     # «Nombre Notificado»
            replacements[key] = _safe_txt(row.get(col, ""))

        # 2) Map de plantilla->col real (para casos como Numero_Documento vs Numero Documento)
        for campo_plantilla, col_real in col_map.items():
            key = f"{izq}{campo_plantilla}{der}"  # «Numero_Documento»
            replacements[key] = _safe_txt(row.get(col_real, ""))

        # Cargar plantilla y reemplazar
        doc = Document(plantilla_path)

        for p in doc.paragraphs:
            _replace_in_paragraph(p, replacements)

        for t in doc.tables:
            _replace_in_table(t, replacements)

        doc.save(ruta_out)
        generados.append({"fila": i, "ruta_docx": ruta_out})

    return pd.DataFrame(generados)

# %%
import os
import pandas as pd
import importlib
import utils as utils_mod

# 1) Recargar utils.py (para que agarre el método nuevo)
importlib.reload(utils_mod)
utils = utils_mod.Utils()  # ajusta si tu clase se instancia diferente

# 2) Verifica que ya existe df_filtrado
print("Existe df_filtrado?", "df_filtrado" in globals())
print("Existe metodo generar_words_desde_plantilla?", hasattr(utils, "generar_words_desde_plantilla"))

# 3) Ruta real de plantilla
PLANTILLA = r"plantillas\NOTIFICACION_POR_AVISO.docx"
print("Existe plantilla?", os.path.exists(PLANTILLA), "->", PLANTILLA)

# 4) Filtrar SOLO Elaborar Oficio (según tu columna REAL)
# Tus columnas reales: "Estado de la Actuacion" y "ACTUACION"
df_oficios = df_filtrado.copy()

df_oficios = df_oficios[
    df_oficios["Estado de la Actuacion"].astype(str).str.strip().str.lower().eq("elaborar oficio")
].copy()

# Excluir ejecutorias (si en ACTUACION aparece EJECUTORIA)
df_oficios = df_oficios[
    ~df_oficios["ACTUACION"].astype(str).str.upper().str.contains("EJECUTORIA", na=False)
].copy()

print("✅ Filas a generar (oficios sin ejecutorias):", len(df_oficios))
# Out:
# Existe df_filtrado? True
# Existe metodo generar_words_desde_plantilla? True
# Existe plantilla? False -> plantillas\NOTIFICACION_POR_AVISO.docx
# ✅ Filas a generar (oficios sin ejecutorias): 32

# %%
print("Existe df_filtrado?", "df_filtrado" in globals())
if "df_filtrado" in globals():
    print("Filas:", len(df_filtrado))
    print("Columnas:", len(df_filtrado.columns))
# Out:
# Existe df_filtrado? True
# Filas: 47
# Columnas: 29

# %% [markdown]
# # Seccion de plantilla para generar words

# %%
from utils import Utils

utils = Utils()

cols = {
    "col_notificador": "Notificador/Revisor",
    "col_estado": "Estado de la Actuacion",
    "col_tipo_oficio": "ACTUACION",
    "col_expediente": "numero_expediente",
    "col_notificado": "Nombre Notificado",
}

display(cols)
# Out:
# {'col_notificador': 'Notificador/Revisor',
#  'col_estado': 'Estado de la Actuacion',
#  'col_tipo_oficio': 'ACTUACION',
#  'col_expediente': 'numero_expediente',
#  'col_notificado': 'Nombre Notificado'}

# %%
print("COLUMNAS REALES DEL DATAFRAME\n")

for c in df_filtrado.columns:
    print(c)
# Out:
# COLUMNAS REALES DEL DATAFRAME
#
# Notificador/Revisor
# numero_expediente
# Regional
# Estado de la Actuacion
# ACTUACION
# Norma Aplicable
# Permisivo/Sancionatorio
# Recurso
# Acto_Administrativo_No_y_fecha
# Recurso_actoadministrativo
# Ordena
# Tipo de Acto Administrativo
# Funcionario que expide
# Nombre Notificado
# Tipo de documento
# Numero Documento
# No. DireccionEfectiva
# Autoriza Notificacion electrónica
# Correo Electronico
# Radicado de autorización Electronica
# Modo de envío
# Tipo de elemento
# Ruta de acceso
# INDICADOR
# DIRECTOR_REGIONAL
# DIRECCION_REGIONAL
# MUNICIPIO_REGIONAL
# articulo_preposicion
# descripcion_con_articulo

# %%
df_words = df_filtrado.copy()

# 1) Agregar info regional faltante para que existan:
#    INDICADOR, DIRECTOR_REGIONAL, DIRECCION_REGIONAL, MUNICIPIO_REGIONAL
df_words = utils.agregar_info_regional(df_words, col_regional="Regional")

# 2) Crear columnas espejo con los nombres exactos que esperan las plantillas Word
df_words["Numero_Documento"] = df_words["Numero Documento"]
df_words["Correo_Electronico"] = df_words["Correo Electronico"]
df_words["No_DireccionEfectiva"] = df_words["No. DireccionEfectiva"]
df_words["Tipo_de_documento"] = df_words["Tipo de documento"]
df_words["Funcionario_que_expide"] = df_words["Funcionario que expide"]
df_words["Nombre_Notificado"] = df_words["Nombre Notificado"]

# 3) Crear modo de envío
#    Regla inicial:
#    - si autoriza notificación electrónica y hay correo -> ELECTRÓNICO
#    - de lo contrario -> FÍSICO
def construir_modo_envio(row):
    autoriza = str(row.get("Autoriza Notificacion electrónica", "")).strip().lower()
    correo = str(row.get("Correo Electronico", "")).strip()

    if autoriza in ["si", "sí", "s", "true", "1", "x"] and correo != "":
        return "ELECTRÓNICO"
    return "FÍSICO"

df_words["Modo_de_envío"] = df_words.apply(construir_modo_envio, axis=1)
df_words["Modo_de_envio"] = df_words["Modo_de_envío"]

print("Filas base words:", len(df_words))
print("Columnas base words:", len(df_words.columns))

columnas_clave = [
    "Numero_Documento",
    "Correo_Electronico",
    "No_DireccionEfectiva",
    "Regional",
    "INDICADOR",
    "DIRECTOR_REGIONAL",
    "Modo_de_envío",
    "numero_expediente",
    "Acto_Administrativo_No_y_fecha",
    "Nombre_Notificado",
    "Tipo_de_documento",
    "Funcionario_que_expide",
    "Recurso_actoadministrativo",
]

print("\nVALIDACIÓN DE COLUMNAS CLAVE:")
for c in columnas_clave:
    print(c, "->", c in df_words.columns)

display(df_words[columnas_clave].head(3))
# Out:
# Filas base words: 47
# Columnas base words: 37
#
# VALIDACIÓN DE COLUMNAS CLAVE:
# Numero_Documento -> True
# Correo_Electronico -> True
# No_DireccionEfectiva -> True
# Regional -> True
# INDICADOR -> True
# DIRECTOR_REGIONAL -> True
# Modo_de_envío -> True
# numero_expediente -> True
# Acto_Administrativo_No_y_fecha -> True
# Nombre_Notificado -> True
# Tipo_de_documento -> True
# Funcionario_que_expide -> True
# Recurso_actoadministrativo -> True
#   Numero_Documento                      Correo_Electronico  \
# 0    899.999.071-0         giovannipadillatellez@gmail.com
# 1    832.004.399-1                  portcasalinda@yahoo.es
# 2    899.999.119-7  procesosjudiciales@procuraduria.gov.co
#
#                No_DireccionEfectiva          Regional INDICADOR  \
# 0  CARRERA 10 N°16-82 PISO 8 Bogotá  Bogota la Calera      DRBC
# 1              Calle 30 No. 1 - 165            Soacha     DRSOA
# 2                 Cra 5 No. 15 - 60            Soacha     DRSOA
#
#              DIRECTOR_REGIONAL Modo_de_envío  numero_expediente  \
# 0  YUBER YESID CARDENAS PULIDO        FÍSICO              40381
# 1   CESAR AUGUSTO RICO MAYORGA   ELECTRÓNICO              81918
# 2   CESAR AUGUSTO RICO MAYORGA   ELECTRÓNICO              73233
#
#                       Acto_Administrativo_No_y_fecha  \
# 0  Resolución DRBC No.  01237000397  de  28 dicie...
# 1  Resolución DJA No. 50267000060 del 17 de febre...
# 2  Resolución DJUR No. 50257000727 del 23 de sept...
#
#                                    Nombre_Notificado Tipo_de_documento  \
# 0  PROCURADURIA 22 JUDICIAL II, AMBIENTAL Y AGRARIA"               NIT
# 1  CONJUNTO RESIDENCIAL PORTAL DE CASALINDA PROPI...               NIT
# 2  PROCURADURIA DELEGADA PARA ASUNTOS AMBIENTALES...               NIT
#
#             Funcionario_que_expide Recurso_actoadministrativo
# 0  MARÍA FERNANDA ZULUAGA MARTÍNEZ                  No Aplica
# 1     EMMA CONSTANZA ZUÑIGA GALVIS                  No Aplica
# 2     EMMA CONSTANZA ZUÑIGA GALVIS                  No aplica

# %%
print("VALORES ÚNICOS DE ACTUACION:\n")
print(sorted(df_words["ACTUACION"].astype(str).str.strip().unique().tolist()))
# Out:
# VALORES ÚNICOS DE ACTUACION:
#
# ['AVISO', 'CITACION', 'COMUNICACION', 'EDICTO', 'EN CONSULTA DR', 'NOTIFICACIÓN ELECTRÓNICA', 'PARA EJECUTORIA', 'PUBLICAR AVISO', 'PUBLICAR CITACION']

# %% [markdown]
# # PASO FINAL

# %%
from docx import Document
from pathlib import Path
import pandas as pd

ruta_plantillas = Path("plantillas")

def extraer_texto_docx(ruta_docx):
    doc = Document(str(ruta_docx))
    partes = []

    for p in doc.paragraphs:
        if p.text.strip():
            partes.append(p.text.strip())

    for t in doc.tables:
        for row in t.rows:
            for cell in row.cells:
                for p in cell.paragraphs:
                    if p.text.strip():
                        partes.append(p.text.strip())

    return "\n".join(partes)

registros = []

for archivo in ruta_plantillas.glob("*.docx"):
    texto = extraer_texto_docx(archivo)

    tiene_marcadores = any(x in texto for x in ["«", ">>", "{{", "["])
    tiene_datos_quemados = any(x in texto for x in [
        "40381",
        "41480",
        "01237000397",
        "50237000469",
        "giovannipadillatellez@gmail.com",
        "comunicacionespgn@procuraduria.gov.co",
        "YUBER YESID CARDENAS PULIDO",
        "PROCURADORIA JUDICIAL"
    ])

    registros.append({
        "archivo": archivo.name,
        "tiene_marcadores": tiene_marcadores,
        "tiene_datos_quemados": tiene_datos_quemados,
        "muestra_texto": texto[:300]
    })

df_revision_plantillas = pd.DataFrame(registros)
display(df_revision_plantillas)
# Out:
#                                           archivo  tiene_marcadores  \
# 0   Formato Aviso Recurso (AUTOMATIZADO) (1).docx              True
# 1  Formato Citación CPACA2011 (Automatizado).docx              True
# 2        Formato Comunicación (Automatizado).docx              True
# 3    Notificación electrónica (Automatizado).docx              True
#
#    tiene_datos_quemados                                      muestra_texto
# 0                 False  DATOS DE ENVIO\n# IDENTIFICACION NOTIFICADO «N...
# 1                 False  DATOS DE ENVIO\n# IDENTIFICACION NOTIFICADO «N...
# 2                 False  DATOS DE ENVIO\n# IDENTIFICACION NOTIFICADO «N...
# 3                 False  DATOS DE ENVIO :\n# IDENTIFICACION NOTIFICADO:...

# %%
import shutil
from pathlib import Path
from utils import Utils

utils = Utils()

# Limpiar salida final
ruta_final = Path("output_abogados")
if ruta_final.exists():
    shutil.rmtree(ruta_final)

# Base final solo para oficios válidos
COL_ESTADO = "Estado de la Actuacion"
COL_ACTUACION = "ACTUACION"

df_oficios = df_filtrado.copy()

df_oficios = df_oficios[
    df_oficios[COL_ESTADO].astype(str).str.strip().str.lower().eq("elaborar oficio")
].copy()

no_validos = ["EJECUTORIA", "EDICTO", "EN CONSULTA DR"]
mask_no_validos = df_oficios[COL_ACTUACION].astype(str).str.upper().apply(
    lambda x: any(p in x for p in no_validos)
)
df_oficios = df_oficios[~mask_no_validos].copy()

df_oficios = utils.agregar_info_regional(df_oficios, col_regional="Regional")

df_oficios["Numero_Documento"] = df_oficios["Numero Documento"]
df_oficios["Correo_Electronico"] = df_oficios["Correo Electronico"]
df_oficios["No_DireccionEfectiva"] = df_oficios["No. DireccionEfectiva"]
df_oficios["Tipo_de_documento"] = df_oficios["Tipo de documento"]
df_oficios["Funcionario_que_expide"] = df_oficios["Funcionario que expide"]
df_oficios["Nombre_Notificado"] = df_oficios["Nombre Notificado"]

def construir_modo_envio(row):
    actuacion = str(row.get("ACTUACION", "")).strip().upper()
    autoriza = str(row.get("Autoriza Notificacion electrónica", "")).strip().lower()
    correo = str(row.get("Correo Electronico", "")).strip()

    if "NOTIFICACIÓN ELECTRÓNICA" in actuacion or "NOTIFICACION ELECTRONICA" in actuacion:
        return "ELECTRÓNICO"
    if autoriza in ["si", "sí", "s", "true", "1", "x"] and correo != "":
        return "ELECTRÓNICO"
    return "FÍSICO"

df_oficios["Modo_de_envío"] = df_oficios.apply(construir_modo_envio, axis=1)
df_oficios["Modo_de_envio"] = df_oficios["Modo_de_envío"]

def homologar_actuacion(x):
    txt = str(x).strip().upper()
    if "AVISO" in txt:
        return "AVISO"
    if "CITACION" in txt:
        return "CITACION"
    if "COMUNICACION" in txt:
        return "COMUNICACION"
    if "NOTIFICACIÓN ELECTRÓNICA" in txt or "NOTIFICACION ELECTRONICA" in txt:
        return "NOTIFICACIÓN ELECTRÓNICA"
    return txt

df_oficios["ACTUACION_NORMALIZADA"] = df_oficios["ACTUACION"].apply(homologar_actuacion)

resumen_final = utils.generar_words_desde_tipo_oficio(
    df=df_oficios,
    carpeta_salida="output_abogados",
    col_notificador="Notificador/Revisor",
    col_estado_actuacion="Estado de la Actuacion",
    col_tipo_oficio="ACTUACION_NORMALIZADA",
    col_subcarpeta=None,
    nombre_archivo_cols=["numero_expediente", "Nombre_Notificado"],
    col_map={}
)

display(resumen_final.head(20))
print("Total generados:", len(resumen_final))

if "error" in resumen_final.columns:
    errores = resumen_final[resumen_final["error"].notna()]
    print("Total errores:", len(errores))
    if len(errores) > 0:
        display(errores.head(50))
# Out:
#     fila                           abogado               tipo_oficio  \
# 0      0       Diana Carolina Morera Acuña              comunicacion
# 1      1    Andrea Claudia Martin Martinez  notificacion_electronica
# 2      2    Andrea Claudia Martin Martinez              comunicacion
# 3      3    Andrea Claudia Martin Martinez              comunicacion
# 4      4           Ana Maria Guzman Acosta                     aviso
# 5      5           Ana Maria Guzman Acosta                     aviso
# 6      6  Laura Stephania Martinez Leandro                     aviso
# 7      7  Laura Stephania Martinez Leandro                     aviso
# 8      8       Diana Carolina Morera Acuña                  citacion
# 9      9       Diana Carolina Morera Acuña                  citacion
# 10    10       Diana Carolina Morera Acuña                     aviso
# 11    11       Diana Carolina Morera Acuña                     aviso
# 12    12       Diana Carolina Morera Acuña              comunicacion
# 13    13       Diana Carolina Morera Acuña                  citacion
# 14    14    Andrea Claudia Martin Martinez  notificacion_electronica
# 15    15       Diana Carolina Morera Acuña                  citacion
# 16    16       Diana Carolina Morera Acuña                     aviso
# 17    17       Diana Carolina Morera Acuña                  citacion
# 18    18       Diana Carolina Morera Acuña                  citacion
# 19    19       Diana Carolina Morera Acuña                  citacion
#
#                                          plantilla  \
# 0         Formato Comunicación (Automatizado).docx
# 1     Notificación electrónica (Automatizado).docx
# 2         Formato Comunicación (Automatizado).docx
# 3         Formato Comunicación (Automatizado).docx
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8   Formato Citación CPACA2011 (Automatizado).docx
# 9   Formato Citación CPACA2011 (Automatizado).docx
# 10                                             NaN
# 11                                             NaN
# 12        Formato Comunicación (Automatizado).docx
# 13  Formato Citación CPACA2011 (Automatizado).docx
# 14    Notificación electrónica (Automatizado).docx
# 15  Formato Citación CPACA2011 (Automatizado).docx
# 16                                             NaN
# 17  Formato Citación CPACA2011 (Automatizado).docx
# 18  Formato Citación CPACA2011 (Automatizado).docx
# 19  Formato Citación CPACA2011 (Automatizado).docx
#
#                                             ruta_docx  \
# 0   output_abogados\Diana_Carolina_Morera_Acuña\WO...
# 1   output_abogados\Andrea_Claudia_Martin_Martinez...
# 2   output_abogados\Andrea_Claudia_Martin_Martinez...
# 3   output_abogados\Andrea_Claudia_Martin_Martinez...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   output_abogados\Diana_Carolina_Morera_Acuña\WO...
# 9   output_abogados\Diana_Carolina_Morera_Acuña\WO...
# 10                                                NaN
# 11                                                NaN
# 12  output_abogados\Diana_Carolina_Morera_Acuña\WO...
# 13  output_abogados\Diana_Carolina_Morera_Acuña\WO...
# 14  output_abogados\Andrea_Claudia_Martin_Martinez...
# 15  output_abogados\Diana_Carolina_Morera_Acuña\WO...
# 16                                                NaN
# 17  output_abogados\Diana_Carolina_Morera_Acuña\WO...
# 18  output_abogados\Diana_Carolina_Morera_Acuña\WO...
# 19  output_abogados\Diana_Carolina_Morera_Acuña\WO...
#
#                                               archivo  \
# 0   OFICIO_40381_PROCURADURIA_22_JUDICIAL_II,_AMBI...
# 1   OFICIO_81918_CONJUNTO_RESIDENCIAL_PORTAL_DE_CA...
# 2   OFICIO_73233_PROCURADURIA_DELEGADA_PARA_ASUNTO...
# 3      OFICIO_93441_ALCALDIA_MUNICIPAL_DE_SOACHA.docx
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8      OFICIO_40388_HECTOR_JAIRO_SARMIENTO_GOMEZ.docx
# 9                   OFICIO_40388_GABRIEL_ESTRADA.docx
# 10                                                NaN
# 11                                                NaN
# 12  OFICIO_41480_PROCURADORIA_JUDICIAL_AMBIENTAL_Y...
# 13                 OFICIO_41564_RAUL_CASTELLANOS.docx
# 14    OFICIO_69585_ÁNGEL_ESNEIDER_RODRIGUEZ_CRUZ.docx
# 15               OFICIO_41564_CARLOS_MUÑOZ_ROJAS.docx
# 16                                                NaN
# 17     OFICIO_41874_JOSÉ_IGNACIO_PRECIADO_GARCÍA.docx
# 18    OFICIO_41874_CARLOS_ARTURO_PRECIADO_GARCÍA.docx
# 19    OFICIO_41874_BLANCA_MARÍA_BAZZANI_DE_AYALA.docx
#
#                                                 error
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   No existe la plantilla: C:\Users\JULIANCHO ROB...
# 5   No existe la plantilla: C:\Users\JULIANCHO ROB...
# 6   No existe la plantilla: C:\Users\JULIANCHO ROB...
# 7   No existe la plantilla: C:\Users\JULIANCHO ROB...
# 8                                                 NaN
# 9                                                 NaN
# 10  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 11  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# Total generados: 30
# Total errores: 10
#     fila                           abogado tipo_oficio plantilla ruta_docx  \
# 4      4           Ana Maria Guzman Acosta       aviso       NaN       NaN
# 5      5           Ana Maria Guzman Acosta       aviso       NaN       NaN
# 6      6  Laura Stephania Martinez Leandro       aviso       NaN       NaN
# 7      7  Laura Stephania Martinez Leandro       aviso       NaN       NaN
# 10    10       Diana Carolina Morera Acuña       aviso       NaN       NaN
# 11    11       Diana Carolina Morera Acuña       aviso       NaN       NaN
# 16    16       Diana Carolina Morera Acuña       aviso       NaN       NaN
# 22    22    Andrea Claudia Martin Martinez       aviso       NaN       NaN
# 26    26           Ana Maria Guzman Acosta       aviso       NaN       NaN
# 28    28  Laura Stephania Martinez Leandro       aviso       NaN       NaN
#
#    archivo                                              error
# 4      NaN  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 5      NaN  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 6      NaN  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 7      NaN  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 10     NaN  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 11     NaN  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 16     NaN  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 22     NaN  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 26     NaN  No existe la plantilla: C:\Users\JULIANCHO ROB...
# 28     NaN  No existe la plantilla: C:\Users\JULIANCHO ROB...
